# %%
import pandas as pd
import numpy as np

# %%
community = pd.read_csv('communities.csv')

# %%
community.head()
# Out:
#     8   ?    ?.1         Lakewoodcity  1  0.19  0.33  0.02   0.9  0.12  ...    \
# 0  53   ?      ?          Tukwilacity  1  0.00  0.16  0.12  0.74  0.45  ...
# 1  24   ?      ?         Aberdeentown  1  0.00  0.42  0.49  0.56  0.17  ...
# 2  34   5  81440  Willingborotownship  1  0.04  0.77  1.00  0.08  0.12  ...
# 3  42  95   6096    Bethlehemtownship  1  0.01  0.55  0.02  0.95  0.09  ...
# 4   6   ?      ?    SouthPasadenacity  1  0.02  0.28  0.06  0.54  1.00  ...
#
#    0.12.2  0.26.1  0.2.1  0.06.3  0.04.2  0.9.1  0.5.2  0.32.2  0.14.3  0.2.2
# 0    0.02    0.12   0.45       ?       ?      ?      ?     0.0       ?   0.67
# 1    0.01    0.21   0.02       ?       ?      ?      ?     0.0       ?   0.43
# 2    0.02    0.39   0.28       ?       ?      ?      ?     0.0       ?   0.12
# 3    0.04    0.09   0.02       ?       ?      ?      ?     0.0       ?   0.03
# 4    0.01    0.58   0.10       ?       ?      ?      ?     0.0       ?   0.14
#
# [5 rows x 128 columns]

# %%
community_num = community._get_numeric_data().columns

# %%
community.loc[:,community_num]
# Out:
#        8   1  0.19  0.33  0.02   0.9  0.12  0.17  0.34  0.47  ...    0.12.1  \
# 0     53   1  0.00  0.16  0.12  0.74  0.45  0.07  0.26  0.59  ...      0.21
# 1     24   1  0.00  0.42  0.49  0.56  0.17  0.04  0.39  0.47  ...      0.14
# 2     34   1  0.04  0.77  1.00  0.08  0.12  0.10  0.51  0.50  ...      0.19
# 3     42   1  0.01  0.55  0.02  0.95  0.09  0.05  0.38  0.38  ...      0.11
# 4      6   1  0.02  0.28  0.06  0.54  1.00  0.25  0.31  0.48  ...      0.70
# 5     44   1  0.01  0.39  0.00  0.98  0.06  0.02  0.30  0.37  ...      0.15
# 6      6   1  0.01  0.74  0.03  0.46  0.20  1.00  0.52  0.55  ...      0.59
# 7     21   1  0.03  0.34  0.20  0.84  0.02  0.00  0.38  0.45  ...      0.01
# 8     29   1  0.01  0.40  0.06  0.87  0.30  0.03  0.90  0.82  ...      0.22
# 9      6   1  0.13  0.71  0.15  0.07  1.00  0.41  0.40  0.52  ...      1.00
# 10    36   1  0.02  0.46  0.08  0.91  0.07  0.10  0.34  0.36  ...      0.20
# ...
